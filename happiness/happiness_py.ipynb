# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedmoustafa/datasets/blob/main/happiness/happiness_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The World Happiness Report Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv ("https://raw.githubusercontent.com/ahmedmoustafa/datasets/main/happiness/happiness2019.csv")
data.shape
# Out:
# (155, 9)

# %%
data.head()
# Out:
#        country        category  score  gdp_per_capita  social_support  \
# 0  Afghanistan  Underdeveloped  3.203           0.350           0.517
# 1      Albania   Transitioning  4.719           0.947           0.848
# 2      Algeria      Developing  5.211           1.002           1.160
# 3    Argentina      Developing  6.086           1.092           1.432
# 4      Armenia   Transitioning  4.559           0.850           1.055
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                    0.361                         0.000       0.158
# 1                    0.874                         0.383       0.178
# 2                    0.785                         0.086       0.073
# 3                    0.881                         0.471       0.066
# 4                    0.815                         0.283       0.095
#
#    perceptions_of_corruption
# 0                      0.025
# 1                      0.027
# 2                      0.114
# ...

# %%
data.tail()
# Out:
#        country        category  score  gdp_per_capita  social_support  \
# 150  Venezuela      Developing  4.707           0.960           1.427
# 151    Vietnam      Developing  5.175           0.741           1.346
# 152      Yemen  Underdeveloped  3.380           0.287           1.163
# 153     Zambia  Underdeveloped  4.107           0.578           1.058
# 154   Zimbabwe      Developing  3.663           0.366           1.114
#
#      healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 150                    0.805                         0.154       0.064
# 151                    0.851                         0.543       0.147
# 152                    0.463                         0.143       0.108
# 153                    0.426                         0.431       0.247
# 154                    0.433                         0.361       0.151
#
#      perceptions_of_corruption
# 150                      0.047
# 151                      0.073
# ...
